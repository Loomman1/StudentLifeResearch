# %%
# About Dataset
# kaggle link: https://www.kaggle.com/datasets/adilshamim8/student-performance-and-learning-style
# This dataset is a SYNTHETIC representation based on true trends in education and career outcomes.

# About the Dataset
# This dataset provides insights into how different study habits, learning styles,
# and external factors influence student performance.
# It includes 10,000 records, covering details about students' study hours,
# online learning participation, exam scores, and other factors impacting academic success.

# Dataset Features
# # Student_ID – Unique identifier for each student
# # Age – Student's age (18-30 years)
# # Gender – Male, Female, or Other
# # Study_Hours_per_Week – Hours spent studying per week (5-50 hours)
# # Preferred_Learning_Style – Visual, Auditory, Reading/Writing, Kinesthetic
# # Online_Courses_Completed – Number of online courses completed (0-20)
# # Participation_in_Discussions – Whether the student actively participates in discussions (Yes/No)
# # Assignment_Completion_Rate (%) – Percentage of assignments completed (50%-100%)
# # Exam_Score (%) – Student’s final exam score (40%-100%)
# # Attendance_Rate (%) – Percentage of classes attended (50%-100%)
# # Use_of_Educational_Tech – Whether the student uses educational technology (Yes/No)
# # Self_Reported_Stress_Level – Student’s stress level (Low, Medium, High)
# # Time_Spent_on_Social_Media (hours/week) – Weekly hours spent on social media (0-30 hours)
# # Sleep_Hours_per_Night – Average sleep duration (4-10 hours)
# # Final_Grade – Assigned grade based on exam score (A, B, C, D, F)



# Импортирование основных библиотек
import pandas as pd              # Для работы с данными в формате DataFrame
import numpy as np               # Для работы с числовыми операциями
import matplotlib.pyplot as plt   # Для визуализации данных
import seaborn as sns            # Для более красивой визуализации по сравнению с matplotlib
! pip install phik
import phik
from phik.report import plot_correlation_matrix
from phik import report

# Установка стиля для графиков
sns.set(style='whitegrid')
! gdown --id 1hj1T8oObTXXNiq-MjZsAwNuWRcsWbx7h
#link='https://drive.google.com/drive/folders/1KyVLjhKrq-RSVeSvRTqm44t5tbmQ2rLv?usp=drive_link' #ссылка на папкугугл диск
# df = pd.read_csv('E:/Python projects/data/students_artificial_dataset/student_performance_large_dataset.csv')
df = pd.read_csv('/content/student_performance_large_dataset.csv', encoding='cp1251')
print(df.head())
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 10.0 MB/s eta 0:00:00
# ...
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1hj1T8oObTXXNiq-MjZsAwNuWRcsWbx7h
# To: /content/student_performance_large_dataset.csv
# 100% 613k/613k [00:00<00:00, 7.54MB/s]
#   Student_ID  Age  Gender  Study_Hours_per_Week Preferred_Learning_Style  \
# 0     S00001   18  Female                    48              Kinesthetic
# 1     S00002   29  Female                    30          Reading/Writing
# 2     S00003   20  Female                    47              Kinesthetic
# 3     S00004   23  Female                    13                 Auditory
# 4     S00005   19  Female                    24                 Auditory
#
# ...

# %%
df
# Out:
#      Student_ID  Age  Gender  Study_Hours_per_Week Preferred_Learning_Style  \
# 0        S00001   18  Female                    48              Kinesthetic
# 1        S00002   29  Female                    30          Reading/Writing
# 2        S00003   20  Female                    47              Kinesthetic
# 3        S00004   23  Female                    13                 Auditory
# 4        S00005   19  Female                    24                 Auditory
# ...         ...  ...     ...                   ...                      ...
# 9995     S09996   20    Male                    30                 Auditory
# 9996     S09997   23  Female                    16                   Visual
# 9997     S09998   26    Male                    23                   Visual
# 9998     S09999   18    Male                    41          Reading/Writing
# 9999     S10000   24    Male                     8                   Visual
#
# ...

# %%
df.groupby('Gender')['Attendance_Rate (%)'].agg(['mean','count'])
# Out:
#              mean  count
# Gender
# Female  74.836360   4846
# Male    75.322452   4748
# Other   75.278325    406

# %%
df.groupby('Gender')['Exam_Score (%)'].agg(['mean','count'])
# Out:
#              mean  count
# Gender
# Female  70.196657   4846
# Male    70.160067   4748
# Other   70.433498    406

# %%
df.groupby('Gender')['Assignment_Completion_Rate (%)'].agg(['mean','count'])
# Out:
#              mean  count
# Gender
# Female  75.014032   4846
# Male    74.821398   4748
# Other   75.000000    406

# %%
#разбить Exam_Score (%) на интервалы (5шт)
df['Exam_score_group']=pd.cut(df['Exam_Score (%)'], 5)
df
# Out:
#      Student_ID  Age  Gender  Study_Hours_per_Week Preferred_Learning_Style  \
# 0        S00001   18  Female                    48              Kinesthetic
# 1        S00002   29  Female                    30          Reading/Writing
# 2        S00003   20  Female                    47              Kinesthetic
# 3        S00004   23  Female                    13                 Auditory
# 4        S00005   19  Female                    24                 Auditory
# ...         ...  ...     ...                   ...                      ...
# 9995     S09996   20    Male                    30                 Auditory
# 9996     S09997   23  Female                    16                   Visual
# 9997     S09998   26    Male                    23                   Visual
# 9998     S09999   18    Male                    41          Reading/Writing
# 9999     S10000   24    Male                     8                   Visual
#
# ...

# %%
# Группировка данных по 'Grade' для женских оценок
female_scores = df[df['Gender'] == 'Female']
female_means = female_scores.groupby('Exam_score_group')['Sleep_Hours_per_Night'].mean()

# Группировка данных по 'Grade' для мужских оценок
male_scores = df[df['Gender'] == 'Male']
male_means = male_scores.groupby('Exam_score_group')['Sleep_Hours_per_Night'].mean()

other_scores = df[df['Gender'] == 'Male']
other_means = other_scores.groupby('Exam_score_group')['Sleep_Hours_per_Night'].mean()

# Построение графиков
plt.figure(figsize=(8, 6))

female_means.plot(kind='bar', position=0, width=0.2, label='Female', color='pink')
male_means.plot(kind='bar', position=1, width=0.2, label='Male', color='lightblue')
other_means.plot(kind='bar', position=2, width=0.2, label='Other', color='green')


plt.title('Average Exam_score_group by Sleep_Hours_per_Night and Gender')
plt.xlabel('Exam_score_group')
plt.ylabel('Average Sleep_Hours_per_Night')
plt.xticks(rotation=0)  # Убираем наклон для меток по оси X
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-47-a2712ace72b9>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   female_means = female_scores.groupby('Exam_score_group')['Sleep_Hours_per_Night'].mean()
# <ipython-input-47-a2712ace72b9>:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   male_means = male_scores.groupby('Exam_score_group')['Sleep_Hours_per_Night'].mean()
# ...

# %%
df
# Out:
#      Student_ID  Age  Gender  Study_Hours_per_Week Preferred_Learning_Style  \
# 0        S00001   18  Female                    48              Kinesthetic
# 1        S00002   29  Female                    30          Reading/Writing
# 2        S00003   20  Female                    47              Kinesthetic
# 3        S00004   23  Female                    13                 Auditory
# 4        S00005   19  Female                    24                 Auditory
# ...         ...  ...     ...                   ...                      ...
# 9995     S09996   20    Male                    30                 Auditory
# 9996     S09997   23  Female                    16                   Visual
# 9997     S09998   26    Male                    23                   Visual
# 9998     S09999   18    Male                    41          Reading/Writing
# 9999     S10000   24    Male                     8                   Visual
#
# ...

# %%
sns.heatmap(df[['Study_Hours_per_Week', 'Exam_Score (%)', 'Online_Courses_Completed', 'Assignment_Completion_Rate (%)',
                'Attendance_Rate (%)', 'Time_Spent_on_Social_Media (hours/week)', 'Sleep_Hours_per_Night']].corr())
# Out:
# <Axes: >

# %%
phik_overview = df.phik_matrix()
# Out:
# interval columns not set, guessing: ['Age', 'Study_Hours_per_Week', 'Online_Courses_Completed', 'Assignment_Completion_Rate (%)', 'Exam_Score (%)', 'Attendance_Rate (%)', 'Time_Spent_on_Social_Media (hours/week)', 'Sleep_Hours_per_Night']
# /usr/local/lib/python3.11/dist-packages/phik/data_quality.py:59: UserWarning: The number of unique values of variable Student_ID is large: 10000. Are you sure this is not an interval variable? Analysis for pairs of variables including Student_ID can be slow.
#   warnings.warn(

# %%
phik_overview = df.phik_matrix()
sns.heatmap(phik_overview)
# Out:
# <Axes: >

# %%
# Группировка данных по 'Final_Grade' для женских оценок
female_scores = df[df['Gender'] == 'Female']
female_means = female_scores.groupby('Final_Grade')['Time_Spent_on_Social_Media (hours/week)'].mean()

# Группировка данных по 'Final_Grade' для мужских оценок
male_scores = df[df['Gender'] == 'Male']
male_means = male_scores.groupby('Final_Grade')['Time_Spent_on_Social_Media (hours/week)'].mean()

# Группировка данных по 'Final_Grade' для мужских оценок
other_scores = df[df['Gender'] == 'Other']
other_means = male_scores.groupby('Final_Grade')['Time_Spent_on_Social_Media (hours/week)'].mean()

# Построение графиков
plt.figure(figsize=(10, 6))

female_means.plot(kind='bar', position=0, width=0.1, label='Female', color='pink')
male_means.plot(kind='bar', position=1, width=0.1, label='Male', color='lightblue')
other_means.plot(kind='bar', position=2, width=0.1, label='Other', color='green')

plt.title('Average Final_Grade by Time_Spent_on_Social_Media (hours/week) and Final_Grade')
plt.xlabel('Final_Grade')
plt.ylabel('Average Time_Spent_on_Social_Media (hours/week)')
plt.xticks(rotation=0)  # Убираем наклон для меток по оси X
plt.legend()
plt.ylim(14, 16)
plt.tight_layout()
plt.show()

# %%
df
# Out:
#      Student_ID  Age  Gender  Study_Hours_per_Week Preferred_Learning_Style  \
# 0        S00001   18  Female                    48              Kinesthetic
# 1        S00002   29  Female                    30          Reading/Writing
# 2        S00003   20  Female                    47              Kinesthetic
# 3        S00004   23  Female                    13                 Auditory
# 4        S00005   19  Female                    24                 Auditory
# ...         ...  ...     ...                   ...                      ...
# 9995     S09996   20    Male                    30                 Auditory
# 9996     S09997   23  Female                    16                   Visual
# 9997     S09998   26    Male                    23                   Visual
# 9998     S09999   18    Male                    41          Reading/Writing
# 9999     S10000   24    Male                     8                   Visual
#
# ...

# %%
# Группировка данных по 'Final_Grade' для женских оценок
means = df.groupby('Final_Grade')['Time_Spent_on_Social_Media (hours/week)'].mean()

# Построение графиков
plt.figure(figsize=(10, 6))

means.plot(kind='bar', position=0, width=0.1, color='green')

plt.title('Average Final_Grade by Time_Spent_on_Social_Media (hours/week) and Final_Grade')
plt.xlabel('Final_Grade')
plt.ylabel('Average Time_Spent_on_Social_Media (hours/week)')
plt.xticks(rotation=0)  # Убираем наклон для меток по оси X
plt.legend()
plt.ylim(14, 16)
plt.tight_layout()
plt.show()

# %%
# Группировка данных по 'Grade' для женских оценок
female_scores = df[df['Gender'] == 'Female']
female_means = female_scores.groupby('Final_Grade')['Attendance_Rate (%)'].mean()

# Группировка данных по 'Grade' для мужских оценок
male_scores = df[df['Gender'] == 'Male']
male_means = male_scores.groupby('Final_Grade')['Attendance_Rate (%)'].mean()

other_scores = df[df['Gender'] == 'Male']
other_means = other_scores.groupby('Final_Grade')['Attendance_Rate (%)'].mean()

# Построение графиков
plt.figure(figsize=(8, 6))

female_means.plot(kind='bar', position=0, width=0.1, label='Female', color='pink')
male_means.plot(kind='bar', position=1, width=0.1, label='Male', color='lightblue')
other_means.plot(kind='bar', position=2, width=0.1, label='Other', color='green')

plt.ylim(74, 76)
plt.title('Average Final_Grade by Attendance_Rate (%) and Gender')
plt.xlabel('Final_Grade')
plt.ylabel('Average Attendance_Rate (%)')
plt.xticks(rotation=0)  # Убираем наклон для меток по оси X
plt.legend()
plt.tight_layout()
plt.show()

# %%
means = df.groupby('Final_Grade')['Attendance_Rate (%)'].mean()

# Построение графиков
plt.figure(figsize=(8, 6))

means.plot(kind='bar', position=0, width=0.1, color='green')

plt.ylim(74, 76)
plt.title('Average Final_Grade by Attendance_Rate (%)')
plt.xlabel('Final_Grade')
plt.ylabel('Average Attendance_Rate (%)')
plt.xticks(rotation=0)  # Убираем наклон для меток по оси X
plt.legend()
plt.tight_layout()
plt.show()

# %%
female_scores = df[df['Gender'] == 'Female']
female_means = female_scores.groupby('Preferred_Learning_Style')['Exam_Score (%)'].mean()

# Группировка данных по 'Grade' для мужских оценок
male_scores = df[df['Gender'] == 'Male']
male_means = male_scores.groupby('Preferred_Learning_Style')['Exam_Score (%)'].mean()

other_scores = df[df['Gender'] == 'Male']
other_means = other_scores.groupby('Preferred_Learning_Style')['Exam_Score (%)'].mean()

# Построение графиков
plt.figure(figsize=(8, 6))

female_means.plot(kind='bar', position=0, width=0.1, label='Female', color='pink')
male_means.plot(kind='bar', position=1, width=0.1, label='Male', color='lightblue')
other_means.plot(kind='bar', position=2, width=0.1, label='Other', color='green')

plt.ylim(60, 80)
plt.title('Average Preferred_Learning_Style by Exam_Score (%)')
plt.xlabel('Preferred_Learning_Style')
plt.ylabel('Average Exam_Score (%)')
plt.xticks(rotation=0)  # Убираем наклон для меток по оси X
plt.legend()
plt.tight_layout()
plt.show()

# %%
means = df.groupby('Preferred_Learning_Style')['Exam_Score (%)'].mean()

# Построение графиков
plt.figure(figsize=(8, 6))

means.plot(kind='bar', position=0, width=0.1, color='green')

plt.ylim(60, 80)
plt.title('Average Preferred_Learning_Style by Exam_Score (%)')
plt.xlabel('Preferred_Learning_Style')
plt.ylabel('Average Exam_Score (%)')
plt.xticks(rotation=0)  # Убираем наклон для меток по оси X
plt.legend()
plt.tight_layout()
plt.show()

# %%
means = df.groupby('Self_Reported_Stress_Level')['Assignment_Completion_Rate (%)'].mean()

# Построение графиков
plt.figure(figsize=(8, 6))

means.plot(kind='bar', position=0, width=0.1, color='green')

# plt.ylim(6, 9)
plt.title('Average Self_Reported_Stress_Level by Assignment_Completion_Rate (%)')
plt.xlabel('Self_Reported_Stress_Level')
plt.ylabel('Average Assignment_Completion_Rate (%)')
plt.xticks(rotation=0)  # Убираем наклон для меток по оси X
plt.legend()
plt.tight_layout()
plt.show()

# %%
df
# Out:
#      Student_ID  Age  Gender  Study_Hours_per_Week Preferred_Learning_Style  \
# 0        S00001   18  Female                    48              Kinesthetic
# 1        S00002   29  Female                    30          Reading/Writing
# 2        S00003   20  Female                    47              Kinesthetic
# 3        S00004   23  Female                    13                 Auditory
# 4        S00005   19  Female                    24                 Auditory
# ...         ...  ...     ...                   ...                      ...
# 9995     S09996   20    Male                    30                 Auditory
# 9996     S09997   23  Female                    16                   Visual
# 9997     S09998   26    Male                    23                   Visual
# 9998     S09999   18    Male                    41          Reading/Writing
# 9999     S10000   24    Male                     8                   Visual
#
# ...

# %%
means = df.groupby('Participation_in_Discussions')['Assignment_Completion_Rate (%)'].mean()

# Построение графиков
plt.figure(figsize=(8, 6))

means.plot(kind='bar', position=0, width=0.1, color='green')

# plt.ylim(6, 9)
plt.title('Average Participation_in_Discussions by Assignment_Completion_Rate (%)')
plt.xlabel('Participation_in_Discussions')
plt.ylabel('Average Assignment_Completion_Rate (%)')
plt.xticks(rotation=0)  # Убираем наклон для меток по оси X
plt.legend()
plt.tight_layout()
plt.show()

# %%
df.dtypes
# Out:
# Student_ID                                   object
# Age                                           int64
# Gender                                       object
# Study_Hours_per_Week                          int64
# Preferred_Learning_Style                     object
# Online_Courses_Completed                      int64
# Participation_in_Discussions                 object
# Assignment_Completion_Rate (%)                int64
# Exam_Score (%)                                int64
# Attendance_Rate (%)                           int64
# Use_of_Educational_Tech                      object
# Self_Reported_Stress_Level                   object
# Time_Spent_on_Social_Media (hours/week)       int64
# Sleep_Hours_per_Night                         int64
# Final_Grade                                  object
# Exam_score_group                           category
# dtype: object

# %%
df['Age'].value_counts()
# Out:
# Age
# 21    875
# 25    858
# 27    852
# 20    849
# 19    846
# 18    838
# 28    830
# 29    825
# 26    822
# 22    813
# 23    810
# 24    782
# Name: count, dtype: int64

# %%
df[df['Gender']=='Other'].head(10)
# Out:
#     Student_ID  Age Gender  Study_Hours_per_Week Preferred_Learning_Style  \
# 9       S00010   28  Other                    35                 Auditory
# 14      S00015   22  Other                    10          Reading/Writing
# 33      S00034   25  Other                     6                   Visual
# 42      S00043   25  Other                    24                 Auditory
# 45      S00046   28  Other                     6                   Visual
# 121     S00122   29  Other                    26                 Auditory
# 128     S00129   26  Other                    40                   Visual
# 135     S00136   28  Other                    27          Reading/Writing
# 173     S00174   27  Other                    21                   Visual
# 257     S00258   21  Other                    24              Kinesthetic
#
#      Online_Courses_Completed Participation_in_Discussions  \
# 9                           7                           No
# ...
